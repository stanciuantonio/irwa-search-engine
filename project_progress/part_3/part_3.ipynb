# %% [markdown]
# # Part 3: Ranking & Filtering

# %%
import os
import sys
import pandas as pd

# Add project root to path
sys.path.insert(0, os.path.abspath('../../'))

from myapp.search.load_corpus import load_preprocessed_corpus
from myapp.search.search_engine import SearchEngine

# %%
# Load preprocessed corpus (same cache as in Part 2)
corpus = load_preprocessed_corpus('../../data/processed/preprocessed_corpus.pkl')

print(f"Loaded {len(corpus)} documents")

# Show example structure
example_pid = list(corpus.keys())[0]
example_doc = corpus[example_pid]
print("\nExample document structure:")
print(f"  PID: {example_doc['pid']}")
print(f"  Tokens (first 10): {example_doc['searchable_text'][:10]}")
print(f"  Metadata: {example_doc['metadata']}")
# Out:
# Loaded 28080 documents
#
# Example document structure:
#   PID: TKPFCZ9EA7H5FYZH
#   Tokens (first 10): ['solid', 'women', 'multicolor', 'track', 'pant', 'yorker', 'trackpant', 'made', '100', 'rich']
#   Metadata: {'category': 'clothing and accessories', 'sub_category': 'bottomwear', 'brand': 'york', 'seller': 'shyam enterprises'}

# %%
TEST_QUERIES = [
    "women cotton dress summer",
    "men leather shoes formal",
    "kids blue jeans comfortable",
    "sports running shoes lightweight",
    "winter jacket warm waterproof"
]

# %%
search_engine = SearchEngine()

# %% [markdown]
# # TF-IDF

# %%
test_query = "cotton sweatshirt"
print(f"Testing TF-IDF for query: '{test_query}'\n")

results = search_engine.search_tfidf(test_query, corpus, top_k=10)

print("\n" + "="*60)
print("Top 10 Results (TF-IDF)")
print("="*60)
for rank, (pid, score) in enumerate(results, 1):
    doc = corpus[pid]
    title = doc['original']['title']
    print(f"{rank:2d}. [{score:6.3f}] {pid} - {title[:60]}")
# Out:
# Testing TF-IDF for query: 'cotton sweatshirt'
#
# Processed query terms: ['cotton', 'sweatshirt']
# Indexed 20906 unique terms from 28080 documents in 0.74s
# Found 1025 documents matching all terms
#
# ============================================================
# Top 10 Results (TF-IDF)
# ============================================================
#  1. [ 0.763] SWSFMTNHCG3SRHJR - Full Sleeve Solid Men Sweatshirt
#  2. [ 0.762] SWSFMTNHEM5SNHVZ - Full Sleeve Solid Women Sweatshirt
#  3. [ 0.733] SWSFMTNHZR59ZUXR - Full Sleeve Solid Men Sweatshirt
#  4. [ 0.654] SWSFXMFPD9RDM2EK - Full Sleeve Printed Men Sweatshirt
#  5. [ 0.649] SWSFXMFPZQGQ6ENA - Full Sleeve Printed Men Sweatshirt
#  6. [ 0.644] SWSFVZRFCWPPZVGT - Full Sleeve Solid Men Sweatshirt
#  7. [ 0.642] SWSFVZRFS7GHGKSF - Full Sleeve Solid Women Sweatshirt
#  8. [ 0.640] SWSFVZRFDEQAKUH2 - Full Sleeve Solid Men Sweatshirt
#  9. [ 0.639] SWSFVZRFTM4P9XGF - Full Sleeve Solid Men Sweatshirt
# 10. [ 0.638] SWSFVZRFVZ2SZ3HZ - Full Sleeve Solid Men Sweatshirt

# %%
# Run all test queries with TF-IDF
tfidf_results = {}

for query in TEST_QUERIES:
    print(f"\n{'='*80}")
    print(f"Query: '{query}'")
    print(f"{'='*80}")

    results = search_engine.search_tfidf(query, corpus, top_k=20)
    tfidf_results[query] = results

    print("\nTop 20 Results (TF-IDF):")
    if results:
        for rank, (pid, score) in enumerate(results, 1):
            doc = corpus[pid]
            title = doc['original']['title']
            brand = doc['original'].get('brand', 'N/A')
            price = doc['original'].get('selling_price', 'N/A')
            rating = doc['original'].get('average_rating', 'N/A')

            print(f"{rank:2d}. [Score: {score:6.3f}] {pid}")
            print(f"    Title: {title[:60]}")
            print(f"    Brand: {brand} | Price: {price} | Rating: {rating}")
    else:
        print("  No results found")
# Out:
# ================================================================================
# Query: 'women cotton dress summer'
# ================================================================================
# Processed query terms: ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.49s
# Found 273 documents matching all terms
#
# Top 20 Results (TF-IDF):
#  1. [Score:  0.161] TSHFVUXNG5VCCCHU
#     Title: Solid Women Polo Neck Red T-Shirt
#     Brand: Shoef | Price: 246 | Rating: 3.6
#  2. [Score:  0.160] TSHFVUXGRXTQPUGH
#     Title: Solid Women Polo Neck Maroon T-Shirt
#     Brand: Shoef | Price: 246 | Rating: 3
#  3. [Score:  0.158] TSHFGBYKFQUMFKKU
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Keo | Price: 664 | Rating: 3.5
#  4. [Score:  0.158] TSHFGBYKFZHSCGGW
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Keo | Price: 664 | Rating: 3.5
#  5. [Score:  0.158] TSHFGDEYGRTC7ZED
#     Title: Solid Women Polo Neck Green, Blue, Black T-Shirt  (Pack of 3
#     Brand: Keo | Price: 664 | Rating: 3.9
#  6. [Score:  0.158] TSHFGBYKUQKCREZJ
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Keo | Price: 664 | Rating: 3.5
#  7. [Score:  0.158] TSHFGBYKCDAEBHT7
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Keo | Price: 664 | Rating: 3.5
#  8. [Score:  0.158] TSHFGBYKEJC36UJF
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Keo | Price: 664 | Rating: 3.5
#  9. [Score:  0.157] TSHFGDEYZ9X7JXFN
#     Title: Solid Women Polo Neck Green, Black, Grey T-Shirt  (Pack of 3
#     Brand: Keo | Price: 616 | Rating: 3.9
# 10. [Score:  0.157] TSHFGBYK3R9GN9CK
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Keo | Price: 664 | Rating: 3.5
# 11. [Score:  0.157] TSHFGDEYCHFV3RGC
#     Title: Solid Women Polo Neck Dark Blue, Green, Black T-Shirt  (Pack
#     Brand: Keo | Price: 664 | Rating: 3.9
# 12. [Score:  0.157] TSHFFWRGSPHAB2GS
#     Title: Solid Women Polo Neck Black, Light Green T-Shirt  (Pack of 2
#     Brand: Keo | Price: 521 | Rating: 1
# 13. [Score:  0.156] TSHFWCRHYSVFWZWH
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
# 14. [Score:  0.156] TSHFWCR44UPHFCHU
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
# 15. [Score:  0.156] TSHFWCRCEQSJUBPR
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
# 16. [Score:  0.156] TSHFFWRGAUUFBE6R
#     Title: Solid Women Polo Neck Grey, Light Green T-Shirt  (Pack of 2)
#     Brand: Keo | Price: 521 | Rating: 1
# 17. [Score:  0.156] TSHFWCSUQR6ECHFG
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
#

# Indexed 20906 unique terms from 28080 documents in 0.46s
# No documents found matching all query terms
#
# Top 20 Results (TF-IDF):
#   No results found

# %% [markdown]
# # BM25

# %%
test_query = "cotton sweatshirt"
print(f"Testing BM25 for query: '{test_query}'\n")

results_bm25 = search_engine.search_bm25(test_query, corpus, top_k=10)

print("\n" + "="*60)
print("Top 10 Results (BM25)")
print("="*60)
for rank, (pid, score) in enumerate(results_bm25, 1):
    doc = corpus[pid]
    title = doc['original']['title']
    print(f"{rank:2d}. [{score:6.3f}] {pid} - {title[:60]}")
# Out:
# Testing BM25 for query: 'cotton sweatshirt'
#
# Processed query terms (BM25): ['cotton', 'sweatshirt']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 1025 documents matching all terms (BM25)
#
# ============================================================
# Top 10 Results (BM25)
# ============================================================
#  1. [ 6.582] SWSFMTNHEM5SNHVZ - Full Sleeve Solid Women Sweatshirt
#  2. [ 6.582] SWSFMTNHZR59ZUXR - Full Sleeve Solid Men Sweatshirt
#  3. [ 6.582] SWSFMTNHCG3SRHJR - Full Sleeve Solid Men Sweatshirt
#  4. [ 6.419] SWSFXZWWYXPZXPTY - Full Sleeve Printed Men Sweatshirt
#  5. [ 6.419] SWSFXZWGMGVDUCXA - Full Sleeve Printed Women Sweatshirt
#  6. [ 6.419] SWSFXZWGFKHNG88S - Full Sleeve Solid Men Sweatshirt
#  7. [ 6.368] SWSFYFFYJCSGNGD8 - Full Sleeve Printed Men Sweatshirt
#  8. [ 6.368] SWSFYFFFMWQMAPJJ - Full Sleeve Printed Men Sweatshirt
#  9. [ 6.342] SWSFYFFFFYZ896TJ - Full Sleeve Printed Women Sweatshirt
# 10. [ 6.323] SWSFXMFPDVRHYYPH - Full Sleeve Striped Women Sweatshirt

# %%
bm25_results = {}

for query in TEST_QUERIES:
    print(f"\n{'='*80}")
    print(f"Query: '{query}'")
    print(f"{'='*80}")

    results = search_engine.search_bm25(query, corpus, top_k=20)
    bm25_results[query] = results

    print("\nTop 20 Results (BM25):")
    if results:
        for rank, (pid, score) in enumerate(results, 1):
            doc = corpus[pid]
            title = doc['original']['title']
            brand = doc['original'].get('brand', 'N/A')
            price = doc['original'].get('selling_price', 'N/A')
            rating = doc['original'].get('average_rating', 'N/A')

            print(f"{rank:2d}. [Score: {score:6.3f}] {pid}")
            print(f"    Title: {title[:60]}")
            print(f"    Brand: {brand} | Price: {price} | Rating: {rating}")
    else:
        print("  No results found")
# Out:
# ================================================================================
# Query: 'women cotton dress summer'
# ================================================================================
# Processed query terms (BM25): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.47s
# Found 273 documents matching all terms (BM25)
#
# Top 20 Results (BM25):
#  1. [Score:  5.817] TSHFVUXNG5VCCCHU
#     Title: Solid Women Polo Neck Red T-Shirt
#     Brand: Shoef | Price: 246 | Rating: 3.6
#  2. [Score:  5.794] TSHFVUXGRXTQPUGH
#     Title: Solid Women Polo Neck Maroon T-Shirt
#     Brand: Shoef | Price: 246 | Rating: 3
#  3. [Score:  5.656] TSHFWCRCEQSJUBPR
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
#  4. [Score:  5.656] TSHFWCR44UPHFCHU
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
#  5. [Score:  5.656] TSHFWCSUQR6ECHFG
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 2)
#     Brand: Shoef | Price: 458 | Rating: 3.6
['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 3 documents matching all terms (BM25)
#
# Top 20 Results (BM25):
#  1. [Score: 17.526] SHOF5BDSWHAMZHSU
#     Title: Running Shoes For Men  (White)
#     Brand: Vector | Price: 720 | Rating: 4.1
#  2. [Score: 16.213] SHOFZP2FHH8Z6ZHC
#     Title: Running Shoes For Women  (Black)
#     Brand: Bone | Price: 474 | Rating: 4
#  3. [Score: 15.962] SHOFKH9ZNNNWCHGC
#     Title: Running Shoes For Men  (Blue)
#     Brand: Bone | Price: 474 | Rating: 3.9
#
# ================================================================================
# Query: 'winter jacket warm waterproof'
# ================================================================================
# Processed query terms (BM25): ['winter', 'jacket', 'warm', 'waterproof']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# No documents found matching all query terms (BM25)
#
# Top 20 Results (BM25):
#   No results found

# %% [markdown]
# ## COMPARISON TF-IDF vs BM25

# %%
import pandas as pd

# As we see in the previous cells, the first query has more results, so we choose this one for the comparison
query = TEST_QUERIES[0]
print(f"Comparing TF-IDF vs BM25 for query:\n  '{query}'\n")

# We execute the search for the query with both models
tfidf_results = search_engine.search_tfidf(query, corpus, top_k=20)
bm25_results = search_engine.search_bm25(query, corpus, top_k=20)

# We convert the results to DataFrames with explicit rank
tfidf_df = pd.DataFrame([
    {
        "Rank_TFIDF": rank,
        "PID_TFIDF": pid,
        "Score_TFIDF": score,
        "Title_TFIDF": corpus[pid]["original"]["title"][:60],
    }
    for rank, (pid, score) in enumerate(tfidf_results, start=1)
])

bm25_df = pd.DataFrame([
    {
        "Rank_BM25": rank,
        "PID_BM25": pid,
        "Score_BM25": score,
        "Title_BM25": corpus[pid]["original"]["title"][:60],
    }
    for rank, (pid, score) in enumerate(bm25_results, start=1)
])

# We merge the two DataFrames by ranking
max_rows = max(len(tfidf_df), len(bm25_df))
tfidf_df = tfidf_df.reindex(range(max_rows))
bm25_df = bm25_df.reindex(range(max_rows))

comparison_df = pd.concat([tfidf_df, bm25_df], axis=1)

print("\n=== TOP-20 COMPARISON: TF-IDF vs BM25 (side by side) ===")
display(comparison_df)
# Out:
# Comparing TF-IDF vs BM25 for query:
#   'women cotton dress summer'
#
# Processed query terms: ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.59s
# Found 273 documents matching all terms
# Processed query terms (BM25): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.61s
# Found 273 documents matching all terms (BM25)
#
# === TOP-20 COMPARISON: TF-IDF vs BM25 (side by side) ===
#     Rank_TFIDF         PID_TFIDF  Score_TFIDF  \
# 0            1  TSHFVUXNG5VCCCHU     0.161370
# 1            2  TSHFVUXGRXTQPUGH     0.159610
# 2            3  TSHFGBYKFQUMFKKU     0.158298
# 3            4  TSHFGBYKFZHSCGGW     0.158078
# 4            5  TSHFGDEYGRTC7ZED     0.158078
# 5            6  TSHFGBYKUQKCREZJ     0.157777
# 6            7  TSHFGBYKCDAEBHT7     0.157634
# 7            8  TSHFGBYKEJC36UJF     0.157594
# 8            9  TSHFGDEYZ9X7JXFN     0.157440
# 9           10  TSHFGBYK3R9GN9CK     0.157418
# 10          11  TSHFGDEYCHFV3RGC     0.156592
# 11          12  TSHFFWRGSPHAB2GS     0.156556
# 12          13  TSHFWCRHYSVFWZWH     0.156394
# 13          14  TSHFWCR44UPHFCHU     0.156370
# 14          15  TSHFWCRCEQSJUBPR     0.156229
# 15          16  TSHFFWRGAUUFBE6R     0.156159
# 16          17  TSHFWCSUQR6ECHFG     0.156108
# 17          18  TSHFGDEYDK7VV3DM     0.156000
# 18          19  TSHFGDDWFPGN3YHN     0.155989
# 19          20  TSHFGBY7JRGFHUUG     0.155909
#
#                                           Title_TFIDF  Rank_BM25  \
# 0                   Solid Women Polo Neck Red T-Shirt          1
# 1                Solid Women Polo Neck Maroon T-Shirt          2
# 2   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          3
# 3   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          4
# 4   Solid Women Polo Neck Green, Blue, Black T-Shi...          5
# 5   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          6
# 6   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          7
# 7   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          8
# 8   Solid Women Polo Neck Green, Black, Grey T-Shi...          9
# 9   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         10
# 10  Solid Women Polo Neck Dark Blue, Green, Black ...         11
# 11  Solid Women Polo Neck Black, Light Green T-Shi...         12
# 12  Solid Women Polo Neck Multicolor T-Shirt  (Pac...         13
# 13  Solid Women Polo Neck Multicolor T-Shirt  (Pac...         14
# 14  Solid Women Polo Neck Multicolor T-Shirt  (Pac...         15
# 15  Solid Women Polo Neck Grey, Light Green T-Shir...         16
# 16  Solid Women Polo Neck Multicolor T-Shirt  (Pac...         17
# 17  Solid Women Polo Neck Green, Maroon, Black T-S...         18
# 18  Solid Women Polo Neck Green, Blue, Maroon T-Sh...         19
# 19   Solid Women Polo Neck Green T-Shirt  (Pack of 3)         20
#
#             PID_BM25  Score_BM25  \
# 0   TSHFVUXNG5VCCCHU    5.817391
# 1   TSHFVUXGRXTQPUGH    5.793817
# 2   TSHFWCRCEQSJUBPR    5.656383
# 3   TSHFWCR44UPHFCHU    5.656383
# 4   TSHFWCSUQR6ECHFG    5.656383
# 5   TSHFWCRC55NY8FHU    5.656383
# 6   TSHFWCSK9YCSUBNZ    5.634124
# 7   TSHFWCQXENGNZRVY    5.634124
# 8   TSHFTT34Z2HPAZUB    5.634124
# 9   TSHFTT32HHGAHPCK    5.634124
# 10  TSHFTT2BHNGZAK2M    5.634124
# 11  TSHFWCRY5JKNFRK6    5.634124
# 12  TSHFTT323Y6EGAFS    5.634124
# 13  TSHFTT23ZASWHHUG    5.634124
# 14  TSHFTT236GUC52NG    5.634124
# 15  TSHFWH6GFZ942BQE    5.634124
# 16  TSHFWCRHYSVFWZWH    5.634124
# 17  TSHFWH6GFHZPJC3B    5.634124
# 18  TSHFWH6GWFY5QV8Z    5.634124
# 19  TSHFTT2TXYGWPU2N    5.634124
#
#                                            Title_BM25
# 0                   Solid Women Polo Neck Red T-Shirt
# 1                Solid Women Polo Neck Maroon T-Shirt
# 2   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 3   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 4   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 5   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 6   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 7   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 8   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 9   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 10  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 11  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 12  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 13  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 14  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 15  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 16  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 17  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 18  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 19  Solid Women Polo Neck Multicolor T-Shirt  (Pac...

# %% [markdown]
# ## Your Score (Custom ranking: BM25 + Rating + Discount + Stock)

# %%
# Test CustomScoreRanker with a simple query
test_query = "cotton sweatshirt"
print(f"Testing Custom Score for query: '{test_query}'\n")

custom_results = search_engine.search_custom(test_query, corpus, top_k=10)

print("\n" + "="*60)
print("Top 10 Results (Custom Score)")
print("="*60)
for rank, (pid, score) in enumerate(custom_results, 1):
    doc = corpus[pid]
    original = doc["original"]
    title = original["title"]
    rating = original.get("average_rating")
    discount = original.get("discount")
    out_of_stock = original.get("out_of_stock")
    print(f"{rank:2d}. [{score:6.3f}] {pid} - {title[:60]}")
    print(f"    Rating: {rating} | Discount: {discount} | Out of stock: {out_of_stock}")
# Out:
# Testing Custom Score for query: 'cotton sweatshirt'
#
# Processed query terms (Custom): ['cotton', 'sweatshirt']
# Indexed 20906 unique terms from 28080 documents in 0.47s
# Found 1025 documents matching all terms (Custom)
#
# ============================================================
# Top 10 Results (Custom Score)
# ============================================================
#  1. [ 4.835] SWSFMTNHZR59ZUXR - Full Sleeve Solid Men Sweatshirt
#     Rating: 4.2 | Discount: 60% off | Out of stock: False
#  2. [ 4.835] SWSFMTNHCG3SRHJR - Full Sleeve Solid Men Sweatshirt
#     Rating: 4.2 | Discount: 60% off | Out of stock: False
#  3. [ 4.830] SWSFMTNHEM5SNHVZ - Full Sleeve Solid Women Sweatshirt
#     Rating: 4.2 | Discount: 55% off | Out of stock: False
#  4. [ 4.685] SWSFXZWWYXPZXPTY - Full Sleeve Printed Men Sweatshirt
#     Rating: 3.2 | Discount: 63% off | Out of stock: False
#  5. [ 4.685] SWSFXZWGMGVDUCXA - Full Sleeve Printed Women Sweatshirt
#     Rating: 3.2 | Discount: 63% off | Out of stock: False
#  6. [ 4.685] SWSFXZWGFKHNG88S - Full Sleeve Solid Men Sweatshirt
#     Rating: 3.2 | Discount: 63% off | Out of stock: False
#  7. [ 4.648] SWSFYFFYJCSGNGD8 - Full Sleeve Printed Men Sweatshirt
#     Rating: 3.2 | Discount: 63% off | Out of stock: False
#  8. [ 4.648] SWSFYFFFMWQMAPJJ - Full Sleeve Printed Men Sweatshirt
#     Rating: 3.2 | Discount: 63% off | Out of stock: False
#  9. [ 4.643] SWSFNV7N26KC54MB - Full Sleeve Solid Women Sweatshirt
#     Rating: 4.3 | Discount: 45% off | Out of stock: False
# 10. [ 4.634] SWSFXMFPZQGQ6ENA - Full Sleeve Printed Men Sweatshirt
#     Rating: 3.7 | Discount: 60% off | Out of stock: False

# %%
# Run all test queries with Custom Score
custom_results_all = {}

for query in TEST_QUERIES:
    print(f"\n{'='*80}")
    print(f"Query: '{query}'")
    print(f"{'='*80}")

    results = search_engine.search_custom(query, corpus, top_k=20)
    custom_results_all[query] = results

    print("\nTop 20 Results (Custom Score):")
    if results:
        for rank, (pid, score) in enumerate(results, 1):
            doc = corpus[pid]
            original = doc["original"]
            title = original["title"]
            brand = original.get("brand", "N/A")
            price = original.get("selling_price", "N/A")
            rating = original.get("average_rating", "N/A")
            discount = original.get("discount", "N/A")
            out_of_stock = original.get("out_of_stock", False)

            print(f"{rank:2d}. [Score: {score:6.3f}] {pid}")
            print(f"    Title: {title[:60]}")
            print(f"    Brand: {brand} | Price: {price} | Rating: {rating} | Discount: {discount} | Out of stock: {out_of_stock}")
    else:
        print("  No results found")
# Out:
# ================================================================================
# Query: 'women cotton dress summer'
# ================================================================================
# Processed query terms (Custom): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0
#     Title: Slip On For Men  (Black)
#     Brand: Bone | Price: 379 | Rating: 3.8 | Discount: 62% off | Out of stock: True
#  7. [Score:  9.854] SHOFVJX2TP8FRR7P
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.8 | Discount: 52% off | Out of stock: False
#  8. [Score:  9.542] SHOFUVZTXJX3NCHF
#     Title: Lace Up For Men  (Brown)
#     Brand: Bone | Price: 474 | Rating: 3.9 | Discount: 52% off | Out of stock: False
#  9. [Score:  9.542] SHOFUVZT6ADKY5VW
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.9 | Discount: 52% off | Out of stock: False
# 10. [Score:  9.319] SHOFVXG5XR59AFTH
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.6 | Discount: 52% off | Out of stock: False
# 11. [Score:  8.077] SHTFCCRGMSBPHSSG
#     Title: Men Slim Fit Checkered Spread Collar Formal Shirt
#     Brand: Adam Park | Price: 1,143 | Rating: 4.5 | Discount: 32% off | Out of stock: False
# 12. [Score:  7.826] TROFYZ5VFZGHHYDG
#     Title: Slim Fit Men Brown Cotton Blend Trousers
#     Brand: Platin | Price: 499 | Rating: 3.9 | Discount: 50% off | Out of stock: False
# 13. [Score:  7.826] TROFYZ5VZSJHVYKF
#     Title: Slim Fit Men Gold Cotton Blend Trousers
#     Brand: Platin | Price: 499 | Rating: 3.9 | Discount: 50% off | Out of stock: False
# 14. [Score:  7.327] TROFYZ5V6YYCKHF5
#     Title: Slim Fit Men Black Cotton Blend Trousers
#     Brand: Platin | Price: 482 | Rating: 3.9 | Discount: 51% off | Out of stock: True
# 15. [Score:  7.326] TROFYZ5VBGUHGNZF
#     Title: Slim Fit Men Khaki Cotton Blend Trousers
#     Brand: Platin | Price: 499 | Rating: 3.9 | Discount: 50% off | Out of stock: True
#
# ================================================================================
# Query: 'kids blue jeans comfortable'
# ================================================================================
# Processed query terms (Custom): ['kid', 'blue', 'jean', 'comfort']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 1 documents matching all terms (Custom)
#
# Top 20 Results (Custom Score):
#  1. [Score:  7.744] CAPFFNNSZKGGFYHY
#     Title: Self Design ROY Caps Combo Pack blue & jeans Cotton Baseball
#     Brand: R | Price: 349 | Rating: 2.8 | Discount: 22% off | Out of stock: False
#
# ================================================================================
# Query: 'sports running shoes lightweight'
# ================================================================================
# Processed query terms (Custom): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.52s
# Found 3 documents matching all terms (Custom)
#
# Top 20 Results (Custom Score):
#  1. [Score: 12.441] SHOF5BDSWHAMZHSU
#     Title: Running Shoes For Men  (White)
#     Brand: Vector | Price: 720 | Rating: 4.1 | Discount: 9% off | Out of stock: False
#  2. [Score: 11.561] SHOFZP2FHH8Z6ZHC
#     Title: Running Shoes For Women  (Black)
#     Brand: Bone | Price: 474 | Rating: 4 | Discount: 52% off | Out of stock: False
#  3. [Score: 11.381] SHOFKH9ZNNNWCHGC
#     Title: Running Shoes For Men  (Blue)
#     Brand: Bone | Price: 474 | Rating: 3.9 | Discount: 52% off | Out of stock: False
#
# ================================================================================
# Query: 'winter jacket warm waterproof'
# ================================================================================
# Processed query terms (Custom): ['winter', 'jacket', 'warm', 'waterproof']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# No documents found matching all query terms (Custom)
#
# Top 20 Results (Custom Score):
#   No results found

# %% [markdown]
# ## Word2Vec + Cosine

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/antoniostanciu/Desktop/university/web-analytics/irwa-search-engine/irwa_venv/lib/python3.12/site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /Users/antoniostanciu/Desktop/university/web-analytics/irwa-search-engine/irwa_venv/lib/python3.12/site-packages (from gensim) (2.2.6)
# Requirement already satisfied: scipy>=1.7.0 in /Users/antoniostanciu/Desktop/university/web-analytics/irwa-search-engine/irwa_venv/lib/python3.12/site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /Users/antoniostanciu/Desktop/university/web-analytics/irwa-search-engine/irwa_venv/lib/python3.12/site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /Users/antoniostanciu/Desktop/university/web-analytics/irwa-search-engine/irwa_venv/lib/python3.12/site-packages (from smart_open>=1.8.1->gensim) (2.0.1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from gensim.models import Word2Vec

# Prepare the training phrases
sentences = [doc["searchable_text"] for doc in corpus.values()]

# Train Word2Vec
w2v_model = Word2Vec(
    sentences=sentences,
    vector_size=100,
    window=10,
    min_count=5,   # or 1 if you want to cover more terms
    sg=1           # skip-gram, default is 0 for CBOW
)

# (optional) save model
w2v_model.save("../../data/word2vec_model.bin")
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
# from gensim.models import Word2Vec
# w2v_model = Word2Vec.load("../../data/word2vec_model.bin")

# %%
# Dictionary token -> vector (list[float]) compatible with Word2VecRanker
embeddings = {word: w2v_model.wv[word].tolist() for word in w2v_model.wv.key_to_index}
len(embeddings), list(embeddings.keys())[:10]
# Out:
# (4418,
#  ['shirt',
#   'neck',
#   'cotton',
#   'wear',
#   'round',
#   'women',
#   '1',
#   'regular',
#   'men',
#   'wash'])

# %%
test_query = "cotton sweatshirt"
print(f"Testing Word2Vec ranking for query: '{test_query}'\n")

results_w2v = search_engine.search_word2vec(test_query, corpus, embeddings, top_k=10)

print("\n" + "="*60)
print("Top 10 Results (Word2Vec)")
print("="*60)
for rank, (pid, score) in enumerate(results_w2v, 1):
    doc = corpus[pid]
    title = doc["original"]["title"]
    print(f"{rank:2d}. [{score:6.3f}] {pid} - {title[:60]}")
# Out:
# Testing Word2Vec ranking for query: 'cotton sweatshirt'
#
# Processed query terms (w2v): ['cotton', 'sweatshirt']
# Indexed 20906 unique terms from 28080 documents in 0.49s
# Found 1025 documents matching all terms (w2v)
#
# ============================================================
# Top 10 Results (Word2Vec)
# ============================================================
#  1. [ 0.851] SWSFXMFP2RUM86QD - Full Sleeve Printed Women Sweatshirt
#  2. [ 0.848] SWSFXMFPRTY4GKGF - Full Sleeve Printed Men Sweatshirt
#  3. [ 0.845] SWSFXMFPNZQGZZNE - Full Sleeve Printed Women Sweatshirt
#  4. [ 0.844] SWSFY5ZHUEZPZZYV - Full Sleeve Printed Women Sweatshirt
#  5. [ 0.844] SWSFXMFPYYTZUZ3Z - Full Sleeve Printed Men Sweatshirt
#  6. [ 0.844] SWSFY5ZHEJ2HYWDG - Full Sleeve Printed Men Sweatshirt
#  7. [ 0.840] SWSFXMFPVYZ2YGGQ - Full Sleeve Embroidered Men Sweatshirt
#  8. [ 0.837] SWSFUNF6XHCGGVCU - Full Sleeve Printed Men Sweatshirt
#  9. [ 0.833] SWSFUNF6ZCFUZKHR - Full Sleeve Printed Men Sweatshirt
# 10. [ 0.832] SWSFUNF6VFJBYZZC - Full Sleeve Printed Men Sweatshirt

# %%
w2v_results = {}

for query in TEST_QUERIES:
    print(f"\n{'='*80}")
    print(f"Query: '{query}'")
    print(f"{'='*80}")

    results = search_engine.search_word2vec(query, corpus, embeddings, top_k=20)
    w2v_results[query] = results

    print("\nTop 20 Results (Word2Vec):")
    if results:
        for rank, (pid, score) in enumerate(results, 1):
            doc = corpus[pid]
            original = doc["original"]
            title = original["title"]
            brand = original.get("brand", "N/A")
            price = original.get("selling_price", "N/A")
            rating = original.get("average_rating", "N/A")

            print(f"{rank:2d}. [Score: {score:6.3f}] {pid}")
            print(f"    Title: {title[:60]}")
            print(f"    Brand: {brand} | Price: {price} | Rating: {rating}")
    else:
        print("  No results found")
# Out:
# ================================================================================
# Query: 'women cotton dress summer'
# ================================================================================
# Processed query terms (w2v): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 273 documents matching all terms (w2v)
#
# Top 20 Results (Word2Vec):
#  1. [Score:  0.713] TSHFSFVMSCXHG7Y8
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#  2. [Score:  0.713] TSHFSFVMYXB3RECU
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 4.2
#  3. [Score:  0.713] TSHFSFVR6ZXHJMSG
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#  4. [Score:  0.713] TSHFSFVHEFPKEVCP
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#  5. [Score:  0.712] TSHFSFVZAQ4G2NT5
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#  6. [Score:  0.712] TSHFSFVHWG4EESGN
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.4
#  7. [Score:  0.712] TSHFSFVQYZWB3DPW
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#  8. [Score:  0.712] TSHFSFVNFRZR3ZNE
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#  9. [Score:  0.712] TSHFSFVPGH5DFUX6
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 10. [Score:  0.712] TSHFSFVHKWRD5HZX
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 11. [Score:  0.712] TSHFSFVNMZKKSYFT
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 2.3
# 12. [Score:  0.712] TSHFWCR46KGKH8WQ
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 654 | Rating: 3.6
# 13. [Score:  0.712] TSHFSFVQQQB9AZGY
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 4.6
# 14. [Score:  0.712] TSHFSFVN9RTR475R
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 15. [Score:  0.712] TSHFSFVQGA4SYWZ5
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 16. [Score:  0.712] TSHFSFVRGZGKCHPT
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 17. [Score:  0.712] TSHFSFVQYECRZURF
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 18. [Score:  0.712] TSHFSFVP4XRRRZQF
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 19. [Score:  0.712] TSHFSFVZTGGVGHGV
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
# 20. [Score:  0.712] TSHFSFVZPNAUGFWZ
#     Title: Solid Women Polo Neck Multicolor T-Shirt  (Pack of 3)
#     Brand: Shoef | Price: 616 | Rating: 3.6
#
# ================================================================================
# Query: 'men leather shoes formal'
# ================================================================================
# Processed query terms (w2v): ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# Found 15 documents matching all terms (w2v)
#
# Top 20 Results (Word2Vec):
#  1. [Score:  0.836] SHOF2HB4B6QHH9BZ
#     Title: Lace Up For Men  (Brown)
#     Brand: Bone | Price: 474 | Rating: 3.9
#  2. [Score:  0.832] SHOF2HB4EKCCJZHS
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 426 | Rating: 3.9
#  3. [Score:  0.768] SHOFUVGYSZMNWNMP
#     Title: Slip On For Men  (Brown)
#     Brand: Bone | Price: 474 | Rating: 3.7
#  4. [Score:  0.767] SHOFUVZTXJX3NCHF
#     Title: Lace Up For Men  (Brown)
#     Brand: Bone | Price: 474 | Rating: 3.9
#  5. [Score:  0.766] SHOFUVGYF9DFWVNV
#     Title: Slip On For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.7
#  6. [Score:  0.764] SHOFUVZT6ADKY5VW
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.9
#  7. [Score:  0.764] SHOFVJX2TP8FRR7P
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.8
#  8. [Score:  0.758] SHOFVXG5XR59AFTH
#     Title: Lace Up For Men  (Black)
#     Brand: Bone | Price: 474 | Rating: 3.6
#  9. [Score:  0.745] SHOFJGUAGAVDZ8CJ
#     Title: Slip On For Men  (Black)
#     Brand: Bone | Price: 379 | Rating: 3.8
# 10. [Score:  0.744] SHOEXDUFMATWVPXA
#     Title: Slip On For Men  (Black)
#     Brand: Bone | Price: 426 | Rating: 4
# 11. [Score:  0.693] TROFYZ5V6YYCKHF5
#     Title: Slim Fit Men Black Cotton Blend Trousers
#     Brand: Platin | Price: 482 | Rating: 3.9
# 12. [Score:  0.692] TROFYZ5VFZGHHYDG
#     Title: Slim Fit Men Brown Cotton Blend Trousers
#     Brand: Platin | Price: 499 | Rating: 3.9
# 13. [Score:  0.692] TROFYZ5VZSJHVYKF
#     Title: Slim Fit Men Gold Cotton Blend Trousers
#     Brand: Platin | Price: 499 | Rating: 3.9
# 14. [Score:  0.688] TROFYZ5VBGUHGNZF
#     Title: Slim Fit Men Khaki Cotton Blend Trousers
#     Brand: Platin | Price: 499 | Rating: 3.9
# 15. [Score:  0.648] SHTFCCRGMSBPHSSG
#     Title: Men Slim Fit Checkered Spread Collar Formal Shirt
#     Brand: Adam Park | Price: 1,143 | Rating: 4.5
#
# ================================================================================
# Query: 'kids blue jeans comfortable'
# ================================================================================
# Processed query terms (w2v): ['kid', 'blue', 'jean', 'comfort']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# Found 1 documents matching all terms (w2v)
#
# Top 20 Results (Word2Vec):
#  1. [Score:  0.687] CAPFFNNSZKGGFYHY
#     Title: Self Design ROY Caps Combo Pack blue & jeans Cotton Baseball
#     Brand: R | Price: 349 | Rating: 2.8
#
# ================================================================================
# Query: 'sports running shoes lightweight'
# ================================================================================
# Processed query terms (w2v): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.59s
# Found 3 documents matching all terms (w2v)
#
# Top 20 Results (Word2Vec):
#  1. [Score:  0.804] SHOF5BDSWHAMZHSU
#     Title: Running Shoes For Men  (White)
#     Brand: Vector | Price: 720 | Rating: 4.1
#  2. [Score:  0.762] SHOFZP2FHH8Z6ZHC
#     Title: Running Shoes For Women  (Black)
#     Brand: Bone | Price: 474 | Rating: 4
#  3. [Score:  0.753] SHOFKH9ZNNNWCHGC
#     Title: Running Shoes For Men  (Blue)
#     Brand: Bone | Price: 474 | Rating: 3.9
#
# ================================================================================
# Query: 'winter jacket warm waterproof'
# ================================================================================
# Processed query terms (w2v): ['winter', 'jacket', 'warm', 'waterproof']
# Indexed 20906 unique terms from 28080 documents in 0.45s
# No documents found matching all query terms (w2v)
#
# Top 20 Results (Word2Vec):
#   No results found

# %% [markdown]
# # COMPARISON ALL MODELS

# %%
# We choose one of the TEST_QUERIES to compare (for example the first one)
query = TEST_QUERIES[0]
print(f"Comparing all 4 models for query:\n  '{query}'\n")

# We rerun the calculation
tfidf = search_engine.search_tfidf(query, corpus, top_k=20)
bm25 = search_engine.search_bm25(query, corpus, top_k=20)
custom = search_engine.search_custom(query, corpus, top_k=20)
w2v = search_engine.search_word2vec(query, corpus, embeddings, top_k=20)

# Convert each ranking into a DataFrame with explicit rank
tfidf_df = pd.DataFrame([
    {
        "Rank_TFIDF": rank,
        "PID_TFIDF": pid,
        "Score_TFIDF": score,
        "Title_TFIDF": corpus[pid]["original"]["title"][:60],
    }
    for rank, (pid, score) in enumerate(tfidf, start=1)
])

bm25_df = pd.DataFrame([
    {
        "Rank_BM25": rank,
        "PID_BM25": pid,
        "Score_BM25": score,
        "Title_BM25": corpus[pid]["original"]["title"][:60],
    }
    for rank, (pid, score) in enumerate(bm25, start=1)
])

custom_df = pd.DataFrame([
    {
        "Rank_Custom": rank,
        "PID_Custom": pid,
        "Score_Custom": score,
        "Title_Custom": corpus[pid]["original"]["title"][:60],
    }
    for rank, (pid, score) in enumerate(custom, start=1)
])

w2v_df = pd.DataFrame([
    {
        "Rank_W2V": rank,
        "PID_W2V": pid,
        "Score_W2V": score,
        "Title_W2V": corpus[pid]["original"]["title"][:60],
    }
    for rank, (pid, score) in enumerate(w2v, start=1)
])

# Reindex all to the same number of rows (maximum of the 4)
max_rows = max(len(tfidf_df), len(bm25_df), len(custom_df), len(w2v_df))
tfidf_df = tfidf_df.reindex(range(max_rows))
bm25_df = bm25_df.reindex(range(max_rows))
custom_df = custom_df.reindex(range(max_rows))
w2v_df = w2v_df.reindex(range(max_rows))

# Concatenate columns -> ranking side by side
comparison_all = pd.concat([tfidf_df, bm25_df, custom_df, w2v_df], axis=1)

print("\n=== TOP-20 COMPARISON: TF-IDF vs BM25 vs Custom vs Word2Vec ===")
display(comparison_all)
# Out:
# Comparing all 4 models for query:
#   'women cotton dress summer'
#
# Processed query terms: ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# Found 273 documents matching all terms
# Processed query terms (BM25): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 273 documents matching all terms (BM25)
# Processed query terms (Custom): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 273 documents matching all terms (Custom)
# Processed query terms (w2v): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.59s
# Found 273 documents matching all terms (w2v)
#
# === TOP-20 COMPARISON: TF-IDF vs BM25 vs Custom vs Word2Vec ===
#     Rank_TFIDF         PID_TFIDF  Score_TFIDF  \
# 0            1  TSHFVUXNG5VCCCHU     0.161370
# 1            2  TSHFVUXGRXTQPUGH     0.159610
# 2            3  TSHFGBYKFQUMFKKU     0.158298
# 3            4  TSHFGBYKFZHSCGGW     0.158078
# 4            5  TSHFGDEYGRTC7ZED     0.158078
# 5            6  TSHFGBYKUQKCREZJ     0.157777
# 6            7  TSHFGBYKCDAEBHT7     0.157634
# 7            8  TSHFGBYKEJC36UJF     0.157594
# 8            9  TSHFGDEYZ9X7JXFN     0.157440
# 9           10  TSHFGBYK3R9GN9CK     0.157418
# 10          11  TSHFGDEYCHFV3RGC     0.156592
# 11          12  TSHFFWRGSPHAB2GS     0.156556
# 12          13  TSHFWCRHYSVFWZWH     0.156394
# 13          14  TSHFWCR44UPHFCHU     0.156370
# 14          15  TSHFWCRCEQSJUBPR     0.156229
# 15          16  TSHFFWRGAUUFBE6R     0.156159
# 16          17  TSHFWCSUQR6ECHFG     0.156108
# 17          18  TSHFGDEYDK7VV3DM     0.156000
# 18          19  TSHFGDDWFPGN3YHN     0.155989
# 19          20  TSHFGBY7JRGFHUUG     0.155909
#
#                                           Title_TFIDF  Rank_BM25  \
# 0                   Solid Women Polo Neck Red T-Shirt          1
# 1                Solid Women Polo Neck Maroon T-Shirt          2
# 2   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          3
# 3   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          4
# 4   Solid Women Polo Neck Green, Blue, Black T-Shi...          5
# 5   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          6
# 6   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          7
# 7   Solid Women Polo Neck Multicolor T-Shirt  (Pac...          8
# 8   Solid Women Polo Neck Green, Black, Grey T-Shi...          9
# 9   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         10
# 10  Solid Women Polo Neck Dark Blue, Green, Black ...         11
# 11  Solid Women Polo Neck Black, Light Green T-Shi...         12
# 12  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 11  TSHFTT34Z2HPAZUB      4.146887
# 12  TSHFTT323Y6EGAFS      4.146887
# 13  TSHFTT23ZASWHHUG      4.146887
# 14  TSHFTT236GUC52NG      4.146887
# 15  TSHFTT2TXYGWPU2N      4.146887
# 16  TSHFTT2SJDRQFZNS      4.146887
# 17  TSHFTT25HXNNBHYR      4.146887
# 18  TSHFTT2YFY9M3ZSY      4.146887
# 19  TSHFTT2U7KFGVFVZ      4.146887
#
#                                          Title_Custom  Rank_W2V  \
# 0                   Solid Women Polo Neck Red T-Shirt         1
# 1                Solid Women Polo Neck Maroon T-Shirt         2
# 2   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         3
# 3   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         4
# 4   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         5
# 5   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         6
# 6   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         7
# 7   Solid Women Polo Neck Multicolor T-Shirt  (Pac...         8
# 8   Solid Women Polo Neck Black, Orange T-Shirt  (...         9
# 9   Solid Women Polo Neck Multicolor T-Shirt  (Pac...        10
# 10  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        11
# 11  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        12
# 12  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        13
# 13  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        14
# 14  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        15
# 15  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        16
# 16  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        17
# 17  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        18
# 18  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        19
# 19  Solid Women Polo Neck Multicolor T-Shirt  (Pac...        20
#
#              PID_W2V  Score_W2V  \
# 0   TSHFSFVMSCXHG7Y8   0.712788
# 1   TSHFSFVMYXB3RECU   0.712595
# 2   TSHFSFVR6ZXHJMSG   0.712588
# 3   TSHFSFVHEFPKEVCP   0.712534
# 4   TSHFSFVZAQ4G2NT5   0.712445
# 5   TSHFSFVHWG4EESGN   0.712294
# 6   TSHFSFVQYZWB3DPW   0.712284
# 7   TSHFSFVNFRZR3ZNE   0.712239
# 8   TSHFSFVPGH5DFUX6   0.712200
# 9   TSHFSFVHKWRD5HZX   0.712200
# 10  TSHFSFVNMZKKSYFT   0.712137
# 11  TSHFWCR46KGKH8WQ   0.712058
# 12  TSHFSFVQQQB9AZGY   0.712044
# 13  TSHFSFVN9RTR475R   0.712023
# 14  TSHFSFVQGA4SYWZ5   0.711995
# 15  TSHFSFVRGZGKCHPT   0.711986
# 16  TSHFSFVQYECRZURF   0.711980
# 17  TSHFSFVP4XRRRZQF   0.711912
# 18  TSHFSFVZTGGVGHGV   0.711898
# 19  TSHFSFVZPNAUGFWZ   0.711894
#
#                                             Title_W2V
# 0   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 1   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 2   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 3   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 4   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 5   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 6   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 7   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 8   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 9   Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 10  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 11  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 12  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 13  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 14  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 15  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 16  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 17  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 18  Solid Women Polo Neck Multicolor T-Shirt  (Pac...
# 19  Solid Women Polo Neck Multicolor T-Shirt  (Pac...

# %%
from myapp.search.evaluation import SearchEvaluator

# Load labels
df = pd.read_csv("../../data/test_queries_labels.csv")

gt_by_query = {}
for qid, group in df.groupby("query_id"):
    if group["labels"].sum() > 0:
        gt_by_query[qid] = dict(zip(group["pid"], group["labels"]))

def eval_model(qid, model_name, ranked_pids):
    evaluator = SearchEvaluator(gt_by_query[qid])
    m = evaluator.evaluate_all(ranked_pids, k_values=[5, 10, 20])
    return {
        "QueryID": qid,
        "Model": model_name,
        "P@10": m["P@10"],
        "R@10": m["R@10"],
        "AP@20": m["AP@20"],
        "MRR": m["MRR"],
        "NDCG@10": m["NDCG@10"],
    }

rows = []
for qid, query in enumerate(TEST_QUERIES, start=1):
    if qid not in gt_by_query:
        continue

    tfidf_rank = [pid for pid, _ in search_engine.search_tfidf(query, corpus, top_k=20)]
    bm25_rank  = [pid for pid, _ in search_engine.search_bm25(query, corpus, top_k=20)]
    custom_rank = [pid for pid, _ in search_engine.search_custom(query, corpus, top_k=20)]
    w2v_rank   = [pid for pid, _ in search_engine.search_word2vec(query, corpus, embeddings, top_k=20)]

    rows.append(eval_model(qid, "TFIDF", tfidf_rank))
    rows.append(eval_model(qid, "BM25", bm25_rank))
    rows.append(eval_model(qid, "Custom", custom_rank))
    rows.append(eval_model(qid, "Word2Vec", w2v_rank))

metrics_df = pd.DataFrame(rows)
metrics_df
# Out:
# Processed query terms: ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 273 documents matching all terms
# Processed query terms (BM25): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# Found 273 documents matching all terms (BM25)
# Processed query terms (Custom): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.59s
# Found 273 documents matching all terms (Custom)
# Processed query terms (w2v): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 273 documents matching all terms (w2v)
# Processed query terms: ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# Found 15 documents matching all terms
# Processed query terms (BM25): ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 15 documents matching all terms (BM25)
# Processed query terms (Custom): ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 15 documents matching all terms (Custom)
# Processed query terms (w2v): ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.68s
# Found 15 documents matching all terms (w2v)
# Processed query terms: ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.45s
# Found 3 documents matching all terms
# Processed query terms (BM25): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.58s
# Found 3 documents matching all terms (BM25)
# Processed query terms (Custom): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 3 documents matching all terms (Custom)
# Processed query terms (w2v): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 3 documents matching all terms (w2v)
#     QueryID     Model  P@10  R@10  AP@20  MRR   NDCG@10
# 0         1     TFIDF   0.5   1.0    1.0  1.0  1.000000
# 1         1      BM25   0.2   0.4    0.4  1.0  0.553146
# 2         1    Custom   0.2   0.4    0.4  1.0  0.553146
# 3         1  Word2Vec   0.0   0.0    0.0  0.0  0.000000
# 4         2     TFIDF   1.0   1.0    1.0  1.0  1.000000
# 5         2      BM25   1.0   1.0    1.0  1.0  1.000000
# 6         2    Custom   1.0   1.0    1.0  1.0  1.000000
# 7         2  Word2Vec   1.0   1.0    1.0  1.0  1.000000
# 8         4     TFIDF   0.3   1.0    1.0  1.0  1.000000
# 9         4      BM25   0.3   1.0    1.0  1.0  1.000000
# 10        4    Custom   0.3   1.0    1.0  1.0  1.000000
# 11        4  Word2Vec   0.3   1.0    1.0  1.0  1.000000

# %% [markdown]
# # EXTRA ALTERNATIVE FOR WORD2VEC

# %%
from gensim.models.fasttext import FastText

# Prepare the training phrases
sentences_ft = [doc["searchable_text"] for doc in corpus.values()]

# Train FastText (parameters inspired by the class notebook)
ft_model = FastText(
    sentences=sentences_ft,
    vector_size=100,    # dimension of the embedding
    window=10,          # large context
    min_count=5,        # ignores rare terms
    negative=15,        # more negative sampling
    sg=1,               # skip-gram
    min_n=2,            # character n-grams [2,5]
    max_n=5
)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
# Dictionary token -> vector (list[float]) compatible with Word2VecRanker
embeddings_ft = {word: ft_model.wv[word].tolist() for word in ft_model.wv.key_to_index}
len(embeddings_ft), list(embeddings_ft.keys())[:10]
# Out:
# (4418,
#  ['shirt',
#   'neck',
#   'cotton',
#   'wear',
#   'round',
#   'women',
#   '1',
#   'regular',
#   'men',
#   'wash'])

# %%
test_query = "cotton sweatshirt"
print(f"Testing FastText ranking for query: '{test_query}'\n")

results_ft = search_engine.search_word2vec(test_query, corpus, embeddings_ft, top_k=10)

print("\n" + "="*60)
print("Top 10 Results (FastText)")
print("="*60)
for rank, (pid, score) in enumerate(results_ft, 1):
    doc = corpus[pid]
    title = doc["original"]["title"]
    print(f"{rank:2d}. [{score:6.3f}] {pid} - {title[:60]}")
# Out:
# Testing FastText ranking for query: 'cotton sweatshirt'
#
# Processed query terms (w2v): ['cotton', 'sweatshirt']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 1025 documents matching all terms (w2v)
#
# ============================================================
# Top 10 Results (FastText)
# ============================================================
#  1. [ 0.920] SWSFXMFPRTY4GKGF - Full Sleeve Printed Men Sweatshirt
#  2. [ 0.918] SWSFXMFP2RUM86QD - Full Sleeve Printed Women Sweatshirt
#  3. [ 0.915] SWSFXMFPYYTZUZ3Z - Full Sleeve Printed Men Sweatshirt
#  4. [ 0.912] SWSFXMFPNZQGZZNE - Full Sleeve Printed Women Sweatshirt
#  5. [ 0.910] SWSFY5ZHEJ2HYWDG - Full Sleeve Printed Men Sweatshirt
#  6. [ 0.909] SWSFUNF6XHCGGVCU - Full Sleeve Printed Men Sweatshirt
#  7. [ 0.908] SWSFY5ZHUEZPZZYV - Full Sleeve Printed Women Sweatshirt
#  8. [ 0.908] SWSFXMFPZQGQ6ENA - Full Sleeve Printed Men Sweatshirt
#  9. [ 0.908] SWSFXMFPD9RDM2EK - Full Sleeve Printed Men Sweatshirt
# 10. [ 0.907] SWSFUNF6VFJBYZZC - Full Sleeve Printed Men Sweatshirt

# %%
ft_results = {}

for query in TEST_QUERIES:
    print(f"\n{'='*80}")
    print(f"Query: '{query}'")
    print(f"{'='*80}")

    results = search_engine.search_word2vec(query, corpus, embeddings_ft, top_k=20)
    ft_results[query] = results

    print("\nTop 20 Results (FastText):")
    if results:
        for rank, (pid, score) in enumerate(results, 1):
            doc = corpus[pid]
            original = doc["original"]
            title = original["title"]
            brand = original.get("brand", "N/A")
            price = original.get("selling_price", "N/A")
            rating = original.get("average_rating", "N/A")

            print(f"{rank:2d}. [Score: {score:6.3f}] {pid}")
            print(f"    Title: {title[:60]}")
            print(f"    Brand: {brand} | Price: {price} | Rating: {rating}")
    else:
        print("  No results found")
# Out:
# ================================================================================
# Query: 'women cotton dress summer'
# ================================================================================
# Processed query terms (w2v): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0
['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 3 documents matching all terms (w2v)
#
# Top 20 Results (FastText):
#  1. [Score:  0.879] SHOF5BDSWHAMZHSU
#     Title: Running Shoes For Men  (White)
#     Brand: Vector | Price: 720 | Rating: 4.1
#  2. [Score:  0.869] SHOFZP2FHH8Z6ZHC
#     Title: Running Shoes For Women  (Black)
#     Brand: Bone | Price: 474 | Rating: 4
#  3. [Score:  0.865] SHOFKH9ZNNNWCHGC
#     Title: Running Shoes For Men  (Blue)
#     Brand: Bone | Price: 474 | Rating: 3.9
#
# ================================================================================
# Query: 'winter jacket warm waterproof'
# ================================================================================
# Processed query terms (w2v): ['winter', 'jacket', 'warm', 'waterproof']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# No documents found matching all query terms (w2v)
#
# Top 20 Results (FastText):
#   No results found

# %%
from myapp.search.evaluation import SearchEvaluator

# 1. Load ground truth of your test queries
df = pd.read_csv("../../data/test_queries_labels.csv")

gt_by_query = {}
for qid, group in df.groupby("query_id"):
    if group["labels"].sum() > 0:    # only queries with at least one relevant
        gt_by_query[qid] = dict(zip(group["pid"], group["labels"]))


def eval_model(qid, model_name, ranked_pids):
    evaluator = SearchEvaluator(gt_by_query[qid])
    m = evaluator.evaluate_all(ranked_pids, k_values=[5, 10, 20])
    return {
        "QueryID": qid,
        "Model": model_name,
        "P@10": m["P@10"],
        "R@10": m["R@10"],
        "AP@20": m["AP@20"],
        "MRR": m["MRR"],
        "NDCG@10": m["NDCG@10"],
    }


rows = []

for qid, query in enumerate(TEST_QUERIES, start=1):
    if qid not in gt_by_query:
        continue

    # Ranking Word2Vec
    w2v_rank = [
        pid for pid, _ in search_engine.search_word2vec(
            query, corpus, embeddings, top_k=20
        )
    ]

    # Ranking FastText (reusing search_word2vec with embeddings_ft)
    ft_rank = [
        pid for pid, _ in search_engine.search_word2vec(
            query, corpus, embeddings_ft, top_k=20
        )
    ]

    rows.append(eval_model(qid, "Word2Vec", w2v_rank))
    rows.append(eval_model(qid, "FastText", ft_rank))

metrics_w2v_ft = pd.DataFrame(rows)
metrics_w2v_ft
# Out:
# Processed query terms (w2v): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.47s
# Found 273 documents matching all terms (w2v)
# Processed query terms (w2v): ['women', 'cotton', 'dress', 'summer']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 273 documents matching all terms (w2v)
# Processed query terms (w2v): ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 15 documents matching all terms (w2v)
# Processed query terms (w2v): ['men', 'leather', 'shoe', 'formal']
# Indexed 20906 unique terms from 28080 documents in 0.60s
# Found 15 documents matching all terms (w2v)
# Processed query terms (w2v): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.63s
# Found 3 documents matching all terms (w2v)
# Processed query terms (w2v): ['sport', 'run', 'shoe', 'lightweight']
# Indexed 20906 unique terms from 28080 documents in 0.46s
# Found 3 documents matching all terms (w2v)
#    QueryID     Model  P@10  R@10     AP@20  MRR   NDCG@10
# 0        1  Word2Vec   0.0   0.0  0.000000  0.0  0.000000
# 1        1  FastText   0.0   0.0  0.000000  0.0  0.000000
# 2        2  Word2Vec   1.0   1.0  1.000000  1.0  1.000000
# 3        2  FastText   0.6   0.6  0.792684  1.0  0.700773
# 4        4  Word2Vec   0.3   1.0  1.000000  1.0  1.000000
# 5        4  FastText   0.3   1.0  1.000000  1.0  1.000000
